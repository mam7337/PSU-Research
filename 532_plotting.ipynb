# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import glob
import os

# %%
FOLDERNAMES = [r'C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-532\20201215_TOI-532\0_results\5_20_30_BEST\Best_Reduction',r'C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-532\20210104_TOI-532\0_results\5_15_30_BEST\best_reduction',
r'C:\Users\Marissa\Desktop\Research\Transits\LCRO\20210104_TOI-532\0_results\6_13_30_BEST',
r'C:\Users\Marissa\Desktop\Research\Transits\RBO\20201207_TOI-532\0_results\17_40_60_BEST\best_reduction',
r'C:\Users\Marissa\Desktop\Research\Transits\ARCTIC\20210201_TOI-532\Q1UW01\UT210202\0_results\13_30_45_BEST\remove_cloudy_points_BEST']

dfs = []
nrows = len(FOLDERNAMES)
fig, ax = plt.subplots(nrows, 1, figsize=(15, 20))

for i, FOLDERNAME in enumerate(FOLDERNAMES):
    os.path.abspath(FOLDERNAME)
    regex = "*w_tot_error.xls"
    files = glob.glob(os.path.join(FOLDERNAME,regex))
    listToStr = ''.join(map(str, files))
    dfs = pd.read_csv(listToStr, sep='\t')
    ax[i].errorbar(x=dfs['BJD(TDB)'], y=dfs['rel_flux_T1'], yerr=dfs['rel_flux_err_T1'],marker='o', markersize=3, elinewidth=1, ls='none')

plt.show()

# %%
df = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-532\20201215_TOI-532\0_results\5_20_30_BEST\Best_Reduction\Processed_l20201215-084408-TOI-532-I_measurements_subset_no_params''', sep='\t')

df_err = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-532\20201215_TOI-532\0_results\5_20_30_BEST\Best_Reduction\Processed_l20201215-084408-TOI-532-I_measurement_w_tot_error.xls''', sep='\t')

df2 = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-532\20210104_TOI-532\0_results\5_15_30_BEST\best_reduction\Processed_l20210105-073107-TOI-532-I_measurements_subset_no_params.dat''', sep='\t')

df2_err = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\TMMT\TOI-532\20210104_TOI-532\0_results\5_15_30_BEST\best_reduction\Processed_l20210105-073107-TOI-532-I_measurement_w_tot_error.xls''', sep='\t')


df3 = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\LCOBOT\20210104_TOI-532\0_results\6_13_30_BEST\Processed_lTOI-532-i-240S-B1-20210105T073125_measurements_subset.dat''', sep='\t')

df3_err = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\LCOBOT\20210104_TOI-532\0_results\6_13_30_BEST\Processed_lTOI-532-i-240S-B1-20210105T073125_measurement_w_tot_error.xls''', sep='\t')

df4 = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\RBO\20201207_TOI-532\0_results\17_40_60_BEST\best_reduction\Processed_la133_datasubset.dat''', sep='\t')

df4_err = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\RBO\20201207_TOI-532\0_results\17_40_60_BEST\best_reduction\Processed_la133_measurement_w_tot_error.xls''', sep='\t')

df5 = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\ARCTIC\20210201_TOI-532\Q1UW01\UT210202\0_results\13_30_45_BEST\remove_cloudy_points_BEST\Processed_Science_sdss_i_4x4_measurements_13_30_45_subset_w_params''', sep='\t')

df5_err = pd.read_csv(r'''C:\Users\Marissa\Desktop\Research\Transits\ARCTIC\20210201_TOI-532\Q1UW01\UT210202\0_results\13_30_45_BEST\remove_cloudy_points_BEST\Processed_Science_sdss_i_4x4_measurements_13_30_45_measurement_w_tot_error.xls''', sep='\t')

# %%
def main():
    nrows = len(FOLDERNAMES)
    fig, ax = plt.subplots(nrows, 1)
    x = dfs['BJD(TDB)']
    y = dfs['rel_flux_T1']
    yerr = dfs['rel_flux_err_T1']
    ax.errorbar(x, y, yerr=yerr,marker='o', markersize=3, elinewidth=1, ls='none')
    plt.show()

main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-247167195028> in <module>
#       8     plt.show()
#       9
# ---> 10 main()
#
# <ipython-input-45-247167195028> in main()
#       5     y = dfs['rel_flux_T1']
#       6     yerr = dfs['rel_flux_err_T1']
# ----> 7     ax.errorbar(x, y, yerr=yerr,marker='o', markersize=3, elinewidth=1, ls='none')
#       8     plt.show()
#       9
#
# AttributeError: 'numpy.ndarray' object has no attribute 'errorbar'

# %%
fig, axs = plt.subplots(len(FOLDERNAMES), 1, figsize=(15,20))
for i in range(len(FOLDERNAMES)):
    axs.errorbar(x=dfs['BJD(TDB)'], y=dfs['rel_flux_T1'], yerr=y_err, marker='o', markersize=3, elinewidth=1, ls='none')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-ba7f4639cd37> in <module>
#       1 fig, axs = plt.subplots(len(FOLDERNAMES), 1, figsize=(15,20))
#       2 for i in range(len(FOLDERNAMES)):
# ----> 3     axs.errorbar(x=dfs['BJD(TDB)'], y=dfs['rel_flux_T1'], yerr=y_err, marker='o', markersize=3, elinewidth=1, ls='none')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'errorbar'

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(15,20))
x = df['BJD(TDB)']
y = df['rel_flux_T1']
med = np.median(y)
y_norm = y/med
y_err = df_err['Total_error']
#y_err_norm = df['rel_flux_err_T1']/med
model_no_params = df['rel_flux_T1_fn_model']
ax1.errorbar(x, y_norm, yerr=y_err, marker='o', markersize=3, elinewidth=1, ls='none')
ax1.errorbar(x, model_no_params, label='UT20201215, TMMT, total error')
ax1.legend(loc='lower left')
ax1.set_ylabel('Relative Flux T1')
ax1.set_xlabel('BJD(TDB)')

x2 = df2['BJD(TDB)']
y2 = df2['rel_flux_T1']
med2 = np.median(y2)
y_norm2 = y2/med2
y_err2 = df2_err['Total_error']
#y_err_norm2 = df2['rel_flux_err_T1']/med2
model_no_params2 = df2['rel_flux_T1_fn_model']
ax2.errorbar(x2, y_norm2, yerr=y_err2, marker='o', markersize=3, elinewidth=1, ls='none')
ax2.errorbar(x2, model_no_params2, label='UT20210104, TMMT, total error')
ax2.legend(loc='lower left')
ax2.set_ylabel('Relative Flux T1')
ax2.set_xlabel('BJD(TDB)')

x3 = df3['BJD(TDB)']
y3 = df3['rel_flux_T1']
med3 = np.median(y3)
y_norm3 = y3/med3
y_err3 = df3_err['Total_error']
#y_err_norm3 = df3['rel_flux_err_T1']/med3
model_no_params3 = df3['rel_flux_T1_fn_model']
ax3.errorbar(x3, y_norm3, yerr=y_err3, marker='o', markersize=3, elinewidth=1, ls='none')
ax3.errorbar(x3, model_no_params3, label='UT20210104, LCRO, total error')
ax3.legend(loc='lower left')
ax3.set_ylabel('Relative Flux T1')
ax3.set_xlabel('BJD(TDB)')

x4 = df4['BJD(TDB)']
y4 = df4['rel_flux_T1']
y4_ingress = df4['rel_flux_T1'][0:68]
med4_ingress = np.median(y4_ingress)
med4 = np.median(y4)
y_norm4 = y4/med4_ingress
y_err4 = df4_err['Total_error']
#y_err_norm4 = df4['rel_flux_err_T1']/med4
model_no_params4 = df4['rel_flux_T1_fn_model']
ax4.errorbar(x4, y_norm4, yerr=y_err4, marker='o', markersize=3, elinewidth=1, ls='none')
ax4.errorbar(x4, model_no_params4, label='UT20201207, RBO, total error')
ax4.legend(loc='lower left')
ax4.set_ylabel('Relative Flux T1')
ax4.set_xlabel('BJD(TDB)')

x5 = df5['BJD(TDB)']
y5 = df5['rel_flux_T1']
y5_egress = df5['rel_flux_T1'][122:159]
med5_egress = np.median(y5_egress)
mean5_egress = np.mean(y5_egress)
med5 = np.median(y5)
mean5 = np.mean(y5)
max5 = np.max(y5)
y_norm5 = y5/mean5_egress
y_err5 = df5_err['Total_error']
#y_err_norm5 = df5['rel_flux_err_T1']
model_w_params5 = df5['rel_flux_T1_fn_model']
ax5.errorbar(x5, y_norm5, yerr=y_err5, marker='o', markersize=3, elinewidth=1, ls='none')
ax5.errorbar(x5, model_w_params5, label='UT20210201, ARCTIC w params, total error, RMS = 0.00125')
ax5.legend(loc='upper left')
ax5.set_ylabel('Relative Flux T1')
ax5.set_xlabel('BJD(TDB)')
# Out:
# Text(0.5, 0, 'BJD(TDB)')

# %%
#Use to plate scale and aperture (ap), inner annulus(in_a), outer annulus (out_a) in PIXELS to calculate the same variables in ARCSECONDS (ap_arc, in_arc, out_arc)

ap = 13.
in_a = 30.
out_a = 45.

arc_ppix_TMMT = 1.194
ap_arc_TMMT = arc_ppix_TMMT * ap
in_arc_TMMT = arc_ppix_TMMT * in_a
out_arc_TMMT = arc_ppix_TMMT * out_a

arc_ppix_LCRO = 0.773
ap_arc_LCRO = arc_ppix_LCRO * ap
in_arc_LCRO = arc_ppix_LCRO * in_a
out_arc_LCRO = arc_ppix_LCRO * out_a

arc_ppix_RBO = 0.532
ap_arc_RBO = arc_ppix_RBO * ap
in_arc_RBO = arc_ppix_RBO * in_a
out_arc_RBO = arc_ppix_RBO * out_a

arc_ppix_ARC = 0.44
ap_arc_ARC = arc_ppix_ARC * ap
in_arc_ARC = arc_ppix_ARC * in_a
out_arc_ARC = arc_ppix_ARC * out_a
print(ap_arc_ARC)
print(in_arc_ARC)
print(out_arc_ARC)
# Out:
# 5.72
# 13.2
# 19.8

# %%
#Calculates number of reference stars in each file
ref_stars = [col for col in df_err.columns if 'rel_flux_C' in col]
n_e = len(ref_stars)
print(n_e)

ref_stars2 = [col for col in df2_err.columns if 'rel_flux_C' in col]
n_e2 = len(ref_stars2)
print(n_e2)

ref_stars3 = [col for col in df3_err.columns if 'rel_flux_C' in col]
n_e3 = len(ref_stars3)
print(n_e3)

ref_stars4 = [col for col in df4_err.columns if 'rel_flux_C' in col]
n_e4 = len(ref_stars4)
print(n_e4)

ref_stars5= [col for col in df5_err.columns if 'rel_flux_C' in col]
n_e5 = len(ref_stars5)
print(n_e5)
# Out:
# 9
# 9
# 13
# 10
# 11

# %%
#Used to check the airmass in the write-up

#print(df_err['AIRMASS']) #TMMT 20201215
#df_err_max = np.max(df_err['AIRMASS'])
#df_err_min = np.min(df_err['AIRMASS'])
#print(df_err_max)
#print(df_err_min)

#print(df2_err['AIRMASS']) #TMMT 20210104
#df2_err_max = np.max(df2_err['AIRMASS'])
#df2_err_min = np.min(df2_err['AIRMASS'])
#print(df2_err_max)
#print(df2_err_min)

#df3_err['AIRMASS'] #LCRO 20210104
print(df3_err['AIRMASS']) #TMMT 20210104
df3_err_max = np.max(df3_err['AIRMASS'])
df3_err_min = np.min(df3_err['AIRMASS'])
print(df3_err_max)
print(df3_err_min)

#df4_err['AIRMASS'] #RBO 20201207
#print(df4_err['AIRMASS']) #TMMT 20210104
#df4_err_max = np.max(df4_err['AIRMASS'])
#df4_err_min = np.min(df4_err['AIRMASS'])
#print(df4_err_max)
#print(df4_err_min)

#df5_err['AIRMASS'] #ARCTIC 20210201
#print(df5_err['AIRMASS']) #TMMT 20210104
#df5_err_max = np.max(df5_err['AIRMASS'])
#df5_err_min = np.min(df5_err['AIRMASS'])
#print(df5_err_max)
#print(df5_err_min)
# Out:
# 0     1.404151
# 1     1.393605
# 2     1.383882
# 3     1.374813
# 4     1.366451
#         ...
# 67    2.767238
# 68    2.879502
# 69    3.003594
# 70    3.138178
# 71    3.288598
# Name: AIRMASS, Length: 72, dtype: float64
# 3.288598
# 1.315167

# %%
#Make a table for TOI-532 data

# %%
# make a table

import numpy as np
import matplotlib.pyplot as plt
data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],
        [ 78415,  81858, 150656, 193263,  69638],
        [139361, 331509, 343164, 781380,  52269]]
columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows = ['%d year' % x for x in (100, 50, 20, 10, 5)]
values = np.arange(0, 2500, 500)
value_increment = 1000
# Get some pastel shades for the colors
colors = plt.cm.BuPu(np.linspace(0, 0.5, len(rows)))
n_rows = len(data)
index = np.arange(len(columns)) + 0.3
bar_width = 0.4
# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))
# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%1.1f' % (x / 1000.0) for x in y_offset])
# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()
# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')
# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)
plt.ylabel("Loss in ${0}'s".format(value_increment))
plt.yticks(values * value_increment, ['%d' % val for val in values])
plt.xticks([])
plt.title('Loss by Disaster')
# plt.show()
# Create image. plt.savefig ignores figure edge and face colors, so map them.
fig = plt.gcf()
plt.savefig('pyplot-table-original.png',
            bbox_inches='tight',
            dpi=150
            )
